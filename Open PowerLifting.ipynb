# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import sklearn
# Out:
# c:\program files (x86)\microsoft visual studio\shared\anaconda3_64\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df = pd.read_csv("C:\\Users\\ruskampm\\Data\\openpowerlifting.csv", 
                dtype={'MeetID': float, 'Name': str, 'Sex': str, 'Equipment': str, 
                       'Age': float, 'Division': str, 'BodyweightKg': float, 
                       'WeightClassKg': str, 'Squat4Kg': float, 'BestSquat4Kg': float,
                       'Bench4Kg': float, 'BestBench4Kg': float,
                       'Deadlift4Kg': float, 'BestDeadlift4Kg': float,
                       'TotalKg': float, 'Place': str, 'Wilks': float})
df.head()
df_reference = df.copy(deep=True)

# %%
df['MeetID'] = df['MeetID'].astype(int)
df = df.drop(['Age'], axis=1)
df.head(10)
# Out:
#    MeetID                    Name Sex   Equipment     Division  BodyweightKg  \
# 0       0        Angie Belk Terry   F       Wraps    Mst 45-49         59.60
# 1       0             Dawn Bogart   F  Single-ply    Mst 40-44         58.51
# 2       0             Dawn Bogart   F  Single-ply  Open Senior         58.51
# 3       0             Dawn Bogart   F         Raw  Open Senior         58.51
# 4       0            Destiny Dula   F         Raw   Teen 18-19         63.68
# 5       0         Courtney Norris   F       Wraps  Open Senior         62.41
# 6       0           Maureen Clary   F         Raw    Mst 60-64         67.31
# 7       0           Maureen Clary   F         Raw  Open Senior         67.31
# 8       0  Priscilla Sweat Pardue   F       Wraps        50-54         65.95
# 9       0  Priscilla Sweat Pardue   F         Raw       Senior         65.95
#
#   WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  Deadlift4Kg  \
# ...

# %%
df = df.drop(['WeightClassKg'], axis=1)
df.head(200)
# Out:
#      MeetID                    Name Sex   Equipment     Division  \
# 0         0        Angie Belk Terry   F       Wraps    Mst 45-49
# 1         0             Dawn Bogart   F  Single-ply    Mst 40-44
# 2         0             Dawn Bogart   F  Single-ply  Open Senior
# 3         0             Dawn Bogart   F         Raw  Open Senior
# 4         0            Destiny Dula   F         Raw   Teen 18-19
# 5         0         Courtney Norris   F       Wraps  Open Senior
# 6         0           Maureen Clary   F         Raw    Mst 60-64
# 7         0           Maureen Clary   F         Raw  Open Senior
# 8         0  Priscilla Sweat Pardue   F       Wraps        50-54
# 9         0  Priscilla Sweat Pardue   F         Raw       Senior
# 10        0            Kayce Hoover   F       Wraps       Junior
# 11        0            Cindy Meeker   F       Wraps    Mst 55-59
# 12        0            Cindy Meeker   F       Wraps  Open Senior
# ...

# %%
df = df.drop(['Squat4Kg'], axis=1)
df = df.drop(['Bench4Kg'], axis=1)
df = df.drop(['Deadlift4Kg'], axis=1)
df.head(200)
# Out:
#      MeetID                    Name Sex   Equipment     Division  \
# 0         0        Angie Belk Terry   F       Wraps    Mst 45-49
# 1         0             Dawn Bogart   F  Single-ply    Mst 40-44
# 2         0             Dawn Bogart   F  Single-ply  Open Senior
# 3         0             Dawn Bogart   F         Raw  Open Senior
# 4         0            Destiny Dula   F         Raw   Teen 18-19
# 5         0         Courtney Norris   F       Wraps  Open Senior
# 6         0           Maureen Clary   F         Raw    Mst 60-64
# 7         0           Maureen Clary   F         Raw  Open Senior
# 8         0  Priscilla Sweat Pardue   F       Wraps        50-54
# 9         0  Priscilla Sweat Pardue   F         Raw       Senior
# 10        0            Kayce Hoover   F       Wraps       Junior
# 11        0            Cindy Meeker   F       Wraps    Mst 55-59
# 12        0            Cindy Meeker   F       Wraps  Open Senior
# ...

# %%
df['Division'].value_counts()
# Out:
# Open                              68618
# Boys                              59641
# R-O                               28667
# Amateur Open                       9396
# R-JR                               7849
# Open Men                           7487
# Junior                             7391
# Junior 19-23                       6695
# Junior 20-23                       6255
# Teen 14-18                         5348
# O                                  4963
# Master 40-49                       4899
# Pro Open                           4767
# Juniors                            4437
# Master 1                           3231
# Master 50-59                       2740
# R-T3                               2397
# Sub-Junior                         2289
# Master 40-44                       2248
# Open Women                         2024
# Master 2                           1982
# R-T2                               1902
# R-C                                1869
# ...

# %%
df_open = df.copy(deep=True)
df_open = df_open[df.Division == "Open" ]
df_open['Division'].value_counts()
# Out:
# Open    68618
# Name: Division, dtype: int64

# %%
df_open['Place'].value_counts()
# Out:
# 1     35998
# 2     13206
# 3      6274
# 4      3354
# DQ     3175
# 5      1961
# 6      1225
# 7       853
# 8       591
# 9       407
# 10      316
# 11      226
# 12      173
# 13      133
# 14      105
# 15       82
# 16       64
# G        50
# 17       50
# 18       34
# 19       26
# DD       25
# 20       22
# 21       16
# 22       15
# 23       13
# 24       11
# 25       10
# 26        8
# 27        7
# 29        6
# 28        6
# 30        5
# NS        4
# 42        3
# 36        3
# 33        3
# 35        3
# 31        3
# 40        3
# 43        3
# 32        3
# 38        3
# 41        3
# 37        3
# 34        3
# 39        3
# 45        1
# 44        1
# 51        1
# 52        1
# 53        1
# 49        1
# 48        1
# 47        1
# 50        1
# 46        1
# Name: Place, dtype: int64

# %%
df_open.head(30)
# Out:
#      MeetID                 Name Sex   Equipment Division  BodyweightKg  \
# 79        1       Maggie Parsons   F         Raw     Open         48.99
# 82        1         Paige Harrod   F         Raw     Open         65.09
# 83        1           Lisha Lamb   F         Raw     Open         71.30
# 84        1      Carley Bradshaw   F         Raw     Open         71.67
# 87        1     Natalie Mayfield   F       Wraps     Open         82.10
# 91        1      Zachary Enokido   M         Raw     Open         74.62
# 94        1           Jacob Lasc   M         Raw     Open         79.83
# 96        1            Bret Lamb   M         Raw     Open         78.24
# 97        1          Jared Morey   M  Single-ply     Open         89.90
# 108       1            John Wise   M         Raw     Open         99.79
# 115       1       Garrett Graham   M         Raw     Open         99.34
# 116       1       Garrett Graham   M         Raw     Open         99.34
# ...
